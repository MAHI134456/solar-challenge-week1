# %% [markdown]
# # exploratory analysis for benin solar dataset
# This notbook performs EDA on the benin solar dataset, including summary statistics ,missing value report, outlier detection, time series analysis, group by cleaning flag, correlation & relationship analysis, wind didtribution analysis, tempreture analysis and buble chart.

# %%
import sys
import os
import pandas as pd

project_root = r'C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1'
os.chdir(project_root)
sys.path.append(project_root)

# Verify working directory and sys.path
print("Current working directory:", os.getcwd())
print("sys.path:", sys.path)

# Import perform_eda from the eda.py file using importlib
import importlib.util

spec = importlib.util.spec_from_file_location("eda", r'C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1\analysis\eda.py')
eda = importlib.util.module_from_spec(spec)
spec.loader.exec_module(eda)
perform_eda = eda.perform_eda

# define input parameters 
csv_file = 'data/benin-malanville.csv'
country = 'benin'
output_dir = 'notbook/benin_eda_output'
os.makedirs(output_dir, exist_ok=True)

# run the eda
df = perform_eda(csv_file, country, output_dir=output_dir)
# Out:
# Current working directory: C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1
# sys.path: ['C:\\Users\\tsion\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\tsion\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'C:\\Users\\tsion\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'C:\\Users\\tsion\\AppData\\Local\\Programs\\Python\\Python313', 'c:\\Users\\tsion\\OneDrive\\Desktop\\solar-challenge-week1\\.venv', '', 'c:\\Users\\tsion\\OneDrive\\Desktop\\solar-challenge-week1\\.venv\\Lib\\site-packages', 'c:\\Users\\tsion\\OneDrive\\Desktop\\solar-challenge-week1\\.venv\\Lib\\site-packages\\win32', 'c:\\Users\\tsion\\OneDrive\\Desktop\\solar-challenge-week1\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\tsion\\OneDrive\\Desktop\\solar-challenge-week1\\.venv\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\tsion\\OneDrive\\Desktop\\solar-challenge-week1']
#
# Summary statistics for benin:
#                            Timestamp            GHI            DNI  \
# count                         525600  525600.000000  525600.000000
# mean   2022-02-07 12:00:30.000000512     240.559452     167.187516
# min              2021-08-09 00:01:00     -12.900000      -7.800000
# 25%              2021-11-08 06:00:45      -2.000000      -0.500000
# 50%              2022-02-07 12:00:30       1.800000      -0.100000
# 75%              2022-05-09 18:00:15     483.400000     314.200000
# max              2022-08-09 00:00:00    1413.000000     952.300000
# std                              NaN     331.131327     261.710501
#
#                  DHI           ModA           ModB           Tamb  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      115.358961     236.589496     228.883576      28.179683
# min       -12.600000       0.000000       0.000000      11.000000
# 25%        -2.100000       0.000000       0.000000      24.200000
# 50%         1.600000       4.500000       4.300000      28.000000
# 75%       216.300000     463.700000     447.900000      32.300000
# max       759.200000    1342.300000    1342.300000      43.800000
# std       158.691074     326.894859     316.536515       5.924297
#
#                   RH             WS         WSgust        WSstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean       54.487969       2.121113       2.809195       0.473390
# min         2.100000       0.000000       0.000000       0.000000
# 25%        28.800000       1.000000       1.300000       0.400000
# 50%        55.100000       1.900000       2.600000       0.500000
# 75%        80.100000       3.100000       4.100000       0.600000
# max       100.000000      19.500000      26.600000       4.200000
# std        28.073069       1.603466       2.029120       0.273395
#
#                   WD        WDstdev             BP       Cleaning  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      153.435172       8.582407     994.197199       0.000923
# min         0.000000       0.000000     985.000000       0.000000
# 25%        59.000000       3.700000     993.000000       0.000000
# 50%       181.000000       8.600000     994.000000       0.000000
# 75%       235.100000      12.300000     996.000000       0.000000
# max       360.000000      99.400000    1003.000000       1.000000
# std       102.332842       6.385864       2.474993       0.030363
#
#        Precipitation          TModA          TModB  Comments
# count  525600.000000  525600.000000  525600.000000       0.0
# mean        0.001905      35.246026      32.471736       NaN
# min         0.000000       9.000000       8.100000       NaN
# 25%         0.000000      24.200000      23.600000       NaN
# 50%         0.000000      30.000000      28.900000       NaN
# 75%         0.000000      46.900000      41.500000       NaN
# max         2.500000      81.000000      72.500000       NaN
# std         0.037115      14.807258      12.348743       NaN
#
# Missing value for benin:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64
#
# Columns with >5% missing values:
# Comments    100.0
# dtype: float64
#
# Outliers (|z|>3) for benin: 7740 rows
# Outliers capped at 1st and 99th percentiles for benin.
# Cleaned data saved to data/benin_clean.csv
# GHI Anomalies (|Z|>3) for benin: 0 rows
# Monthly Averages for benin:
#               GHI         DNI         DHI       Tamb
# Month
# 1      236.128862  222.525260   85.082361  23.328141
# 2      261.661136  183.415588  123.495055  25.814008
# 3      246.705580  101.956669  157.667092  31.699034
# 4      268.215912  160.633539  134.281343  33.773639
# 5      255.739586  147.101019  135.264615  32.495177
# 6      232.424106  144.549961  118.485560  29.332551
# 7      221.273121  130.075206  121.098248  27.329886
# 8      197.711266   98.911617  121.674964  26.489048
# 9      221.551630  128.115174  121.677116  27.157532
# 10     261.254857  221.985128   95.802708  29.229462
# 11     249.525183  255.419722   75.578123  27.419646
# 12     230.106250  210.786277   89.963551  24.019283
# Hourly Averages for benin:
#              GHI         DNI         DHI
# Hour
# 0      -2.713215   -0.440169   -3.135251
# 1      -2.665279   -0.432000   -3.081388
# 2      -2.599744   -0.424096   -3.024795
# 3      -2.561333   -0.413215   -2.997484
# 4      -2.561110   -0.407082   -3.004306
# 5      -2.547635   -0.404667   -2.996845
# 6       2.885370    0.913772    2.279301
# 7      82.742233   72.299219   64.748731
# 8     264.109817  237.551826  162.885594
# 9     462.279050  354.075749  242.170534
# 10    650.925379  436.135881  308.838758
# 11    774.332041  482.196895  341.748174
# 12    822.403936  497.978936  351.812416
# 13    806.768096  490.438936  350.489068
# 14    729.156575  470.153292  327.845434
# 15    581.433219  418.568265  280.796000
# 16    392.096662  335.601205  211.211973
# 17    186.989105  187.929580  121.797566
# 18     34.070260   27.791301   28.012644
# 19     -2.990685   -0.647297   -3.520543
# 20     -3.210530   -0.579073   -3.702703
# 21     -3.013260   -0.525169   -3.488361
# 22     -2.888900   -0.490187   -3.330100
# 23     -2.800260   -0.465452   -3.229890
#
# Cleaning Impact for benin:
#                 ModA        ModB
# Cleaning
# 0         236.165455  228.385370
# 1         307.229278  301.972165
# C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1\analysis\eda.py:150: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ws_mean = df['WS'].groupby(wd_binned).mean()
