# %% [markdown]
# # exploratory analysis for  togo
# This notbook performs EDA on the togo solar dataset, including summary statistics ,missing value report, outlier detection, time series analysis, group by cleaning flag, correlation & relationship analysis, wind didtribution analysis, tempreture analysis and buble chart.

# %%
# Ensure pandas is installed
# %pip install pandas
# %pip install -r ../requirements.txt
# import the perform_eda function
import sys
import os
import pandas as pd
project_root = r'C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1'
os.chdir(project_root)
sys.path.append(project_root)

# Verify working directory and sys.path
print("Current working directory:", os.getcwd())
print("sys.path:", sys.path)
 
# Import perform_eda from the eda.py file using importlib
import importlib.util

spec = importlib.util.spec_from_file_location("eda", r'C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1\analysis\eda.py')
eda = importlib.util.module_from_spec(spec)
spec.loader.exec_module(eda)
perform_eda = eda.perform_eda

# define input parameters 
csv_file = 'data/togo-dapaong_qc.csv'
country = 'togo'
output_dir = 'analysis'
# run the eda
df = perform_eda(csv_file, country, output_dir=output_dir)
# Out:
# Requirement already satisfied: pandas in c:\users\tsion\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\tsion\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tsion\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tsion\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tsion\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tsion\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '../requirements.txt'
# Note: you may need to restart the kernel to use updated packages.
# Current working directory: C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1
# sys.path: ['c:\\Users\\tsion\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'c:\\Users\\tsion\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'c:\\Users\\tsion\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'c:\\Users\\tsion\\AppData\\Local\\Programs\\Python\\Python313', '', 'C:\\Users\\tsion\\AppData\\Roaming\\Python\\Python313\\site-packages', 'C:\\Users\\tsion\\AppData\\Roaming\\Python\\Python313\\site-packages\\win32', 'C:\\Users\\tsion\\AppData\\Roaming\\Python\\Python313\\site-packages\\win32\\lib', 'C:\\Users\\tsion\\AppData\\Roaming\\Python\\Python313\\site-packages\\Pythonwin', 'c:\\Users\\tsion\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages', 'C:\\Users\\tsion\\OneDrive\\Desktop\\solar-challenge-week1', 'C:\\Users\\tsion\\OneDrive\\Desktop\\solar-challenge-week1']
#
# Summary statistics for togo:
#                            Timestamp            GHI            DNI  \
# count                         525600  525600.000000  525600.000000
# mean   2022-04-25 12:00:30.000000768     230.555040     151.258469
# min              2021-10-25 00:01:00     -12.700000       0.000000
# 25%              2022-01-24 06:00:45      -2.200000       0.000000
# 50%              2022-04-25 12:00:30       2.100000       0.000000
# 75%              2022-07-25 18:00:15     442.400000     246.400000
# max              2022-10-25 00:00:00    1424.000000    1004.500000
# std                              NaN     322.532347     250.956962
#
#                  DHI           ModA           ModB           Tamb  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      116.444352     226.144375     219.568588      27.751788
# min         0.000000       0.000000       0.000000      14.900000
# 25%         0.000000       0.000000       0.000000      24.200000
# 50%         2.500000       4.400000       4.300000      27.200000
# 75%       215.700000     422.525000     411.000000      31.100000
# max       805.700000    1380.000000    1367.000000      41.400000
# std       156.520714     317.346938     307.932510       4.758023
#
#                   RH             WS         WSgust        WSstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean       55.013160       2.368093       3.229490       0.557740
# min         3.300000       0.000000       0.000000       0.000000
# 25%        26.500000       1.400000       1.900000       0.400000
# 50%        59.300000       2.200000       2.900000       0.500000
# 75%        80.800000       3.200000       4.400000       0.700000
# max        99.800000      16.100000      23.100000       4.700000
# std        28.778732       1.462668       1.882565       0.268923
#
#                   WD        WDstdev             BP       Cleaning  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      161.741845      10.559568     975.915242       0.000535
# min         0.000000       0.000000     968.000000       0.000000
# 25%        74.800000       6.900000     975.000000       0.000000
# 50%       199.100000      10.800000     976.000000       0.000000
# 75%       233.500000      14.100000     977.000000       0.000000
# max       360.000000      86.900000     983.000000       1.000000
# std        91.877217       5.915490       2.153977       0.023116
#
#        Precipitation          TModA          TModB  Comments
# count  525600.000000  525600.000000  525600.000000       0.0
# mean        0.001382      32.444403      33.543330       NaN
# min         0.000000      13.100000      13.100000       NaN
# 25%         0.000000      23.900000      23.600000       NaN
# 50%         0.000000      28.400000      28.400000       NaN
# 75%         0.000000      40.600000      43.000000       NaN
# max         2.300000      70.400000      94.600000       NaN
# std         0.026350      10.998334      12.769277       NaN
#
# Missing value for togo:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64
#
# Columns with >5% missing values:
# Comments    100.0
# dtype: float64
#
# Outliers (|z|>3) for togo: 9251 rows
# Cleaned data saved to data/togo_clean.csv
# GHI Anomalies (|Z|>3) for togo: 305 rows
# Monthly Averages for togo:
#               GHI         DNI         DHI       Tamb
# Month
# 1      238.426918  219.422166   90.369834  25.132681
# 2      257.658819  172.229457  131.359266  28.268621
# 3      252.169276  114.931635  157.590645  32.511519
# 4      252.307278  143.576257  131.567965  30.888090
# 5      238.432717  129.297993  128.203943  29.719371
# 6      237.576118  133.510521  124.700926  27.732884
# 7      203.113380   94.875930  124.710381  26.264928
# 8      189.017236   81.059830  123.404628  25.294935
# 9      177.739558   83.204699  111.767359  24.970475
# 10     245.758793  177.941514  109.592782  27.142251
# 11     245.349884  253.428850   75.008317  28.900421
# 12     231.435146  213.932435   89.766243  26.293190
# Hourly Averages for togo:
#              GHI         DNI         DHI
# Hour
# 0      -2.264968    0.000000    0.000000
# 1      -2.174954    0.000000    0.000000
# 2      -2.112836    0.000000    0.000000
# 3      -2.120370    0.000000    0.000000
# 4      -2.082365    0.000000    0.000000
# 5      -0.457525    0.300146    1.128315
# 6      53.039018   42.047489   43.532808
# 7     211.594511  181.295352  137.776311
# 8     409.281333  307.181324  223.985174
# 9     589.945005  390.403881  291.282027
# 10    717.561895  434.611621  335.921406
# 11    783.734164  450.521877  361.833708
# 12    779.221680  452.080320  354.978356
# 13    719.238416  436.553849  334.519977
# 14    603.526511  401.916918  293.618037
# 15    420.818068  313.474553  228.199324
# 16    216.198804  180.806817  140.855900
# 17     54.030954   38.613123   45.469315
# 18     -1.176909    0.395986    1.563799
# 19     -2.785123    0.000000    0.000000
# 20     -2.553543    0.000000    0.000000
# 21     -2.429836    0.000000    0.000000
# 22     -2.385521    0.000000    0.000000
# 23     -2.325457    0.000000    0.000000
#
# Cleaning Impact for togo:
#                 ModA        ModB
# Cleaning
# 0         225.979064  219.401351
# 1         535.186477  532.211744
# C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1\analysis\eda.py:142: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ws_mean = df['WS'].groupby(wd_binned).mean()
