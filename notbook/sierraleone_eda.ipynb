# %% [markdown]
# # exploratory analysis for sierraleone
# this notebook performs EDA on the Seirralione solar dataset , including summary statistics , missing value report, outlier detection, time series analysis, group by cleaning flag, correlation & relationship analysis, wind distribution analysis, temperature analysis and buble chart.

# %%
# Ensure pandas is installed
# %pip install pandas
# %pip install -r ../requirements.txt
# import the perform_eda function
import sys
import os
import pandas as pd
project_root = r'C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1'
os.chdir(project_root)
sys.path.append(project_root)

# Verify working directory and sys.path
print("Current working directory:", os.getcwd())
print("sys.path:", sys.path)
 
# Import perform_eda from the eda.py file using importlib
import importlib.util

spec = importlib.util.spec_from_file_location("eda", r'C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1\analysis\eda.py')
eda = importlib.util.module_from_spec(spec)
spec.loader.exec_module(eda)
perform_eda = eda.perform_eda

# define input parameters 
csv_file = 'data/sierraleone-bumbuna.csv'
country = 'sierraleone'
output_dir = 'notbook/sierraleone_eda_output'
# create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)
# run the eda
df = perform_eda(csv_file, country, output_dir=output_dir)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# Current working directory: C:\Users\tsion\OneDrive\Desktop\solar-challenge-week1
# ...
